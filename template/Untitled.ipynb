# %%
import integrated_model as im
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\AYUTRI~1\AppData\Local\Temp/ipykernel_8032/441779292.py in <module>
# ----> 1 import integrated_model as im
#
# ModuleNotFoundError: No module named 'integrated_model'

# %%
data = im.ProcessData("Data Orbit - Data Gabungan.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\AYUTRI~1\AppData\Local\Temp/ipykernel_8032/2853062718.py in <module>
# ----> 1 data = im.ProcessData("Data Orbit - Data Gabungan.csv")
#
# NameError: name 'im' is not defined

# %%
data.min_rating
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\AYUTRI~1\AppData\Local\Temp/ipykernel_8032/1592983470.py in <module>
# ----> 1 data.min_rating
#
# NameError: name 'data' is not defined

# %%
data.run_preprocessing()
# Out:
# 781
# 100
# Number of User: 781, Number of Tempat: 100, Min Rating: 1.0, Max Rating: 5.0
# Epoch 1/100
# 82/82 [==============================] - 1s 3ms/step - loss: 0.6978 - root_mean_squared_error: 0.4430 - val_loss: 0.6983 - val_root_mean_squared_error: 0.4381
# Epoch 2/100
# 82/82 [==============================] - 0s 2ms/step - loss: 0.5731 - root_mean_squared_error: 0.3673 - val_loss: 0.6900 - val_root_mean_squared_error: 0.4333
# Epoch 3/100
# 82/82 [==============================] - 0s 969us/step - loss: 0.4895 - root_mean_squared_error: 0.3107 - val_loss: 0.6843 - val_root_mean_squared_error: 0.4300
# Epoch 4/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.4398 - root_mean_squared_error: 0.2767 - val_loss: 0.6803 - val_root_mean_squared_error: 0.4276
# Epoch 5/100
# 82/82 [==============================] - 0s 1ms/step - loss: 0.4187 - root_mean_squared_error: 0.2636 - val_loss: 0.6777 - val_root_mean_squared_error: 0.4261
# Epoch 6/100
# ...

# %%
data.getData()
# Out:
# Menampilkan Rekomendasi  Tempat Makan dan Lokasi untuk Pengguna dengan Total : u0498 Pengguna
# ...
# Warung Babi Guling Ken Arok : Denpasar Utara : 21_a,21_b,21_c,21_d,21_e : Nasi Babi Guling Hemat, Nasi Babi Guling Spesial, Nasi Babi Guling Biasa Gen, Nasi Babi Guling Campur, Kerupuk Kulit Ayam Jumbo
# ---------------------------------
# 10 Rekomendasi tempat makan
# ---------------------------------
# Warung Made : Denpasar Timur : 15_a : Mie Goreng, Mie Goreng Mawut, Ikan Goreng Lalapan, Nasi Goreng Bali, Cap Cay
# Warung Nasi Tekor Bali : Denpasar Timur : 22_a,22_b : Nasi Campur Biasa, Nasi Campur Spesial, Rujak Kuah Pindang, Tipat Cantok, Rujak Gula Bali
# Warung Bu Komang : Denpasar Timur : 25_a : Nasi Campur Biasa, Nasi Campur Spesial, Babi Kecap, Sop Babi, Babi Panggang
# Warung Makan Bu Kadek : Denpasar : 50_a,50_b,50_c : Nasi Campur Spesial, Nasi Campur B2 Rica, Babi Goreng, Sup Babi, Nasi Campur Istimewa
# ...
